# %% [markdown]
# # IRIS Flower Classification ML Project
#
# ## Mayank Samadhiya
#
# ## VIT BHOPAL UNIVERSITY
#
# ## LetsGrowMore
#
# #### LinkDin Profile ----> https://www.linkedin.com/in/mayank-samadhiya-6827301a7/
# #### GitHub Profile  ----> https://github.com/mayanksamadhiya12345

# %%
# here we are declaring liberaries 

import numpy as np                           # for mathematical operations
import pandas as pd                          # for data analysis
import seaborn as sns                        # for loadinf the data
import matplotlib.pyplot as plt              # for data visualization
# %matplotlib inline

sns.set()

# %% [markdown]
# # Importing Datasets
#
#  1.First we load our dataset through sns.load_dataset()
#
#  2.After loading it is important to check the complete information of data as it can indication many of the hidden infomation       such as null values in a column or a row
#
#  3.Check whether any null values are there or not. if it is present then following can be done,
#             A. Imputing data using Imputation method in sklearn
#             B. Filling NaN values with mean, median and mode using fillna() method
#
#  4.Describe data --> which can give statistical analysis

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
ax = iris.plot(figsize=(15,8), title='Iris Dataset')
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
# Out:
# Text(0, 0.5, 'Y Axis')

# %%
iris.shape
# Out:
# (150, 5)

# %% [markdown]
# ### check the null values for each column

# %%
iris.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
iris.shape
# Out:
# (150, 5)

# %% [markdown]
# # EDA and DV
#
# here we can see that species column is not having much information so we will drop it from our dataset

# %%
df = iris.drop(['species'], axis = 1)

# %% [markdown]
# ### for first row data

# %%
df.iloc[0]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
df.iloc[0].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Histograms For Visualization

# %%
iris.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind = 'hist', stacked = False, bins = 20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind = 'hist', stacked = True, bins = 10, orientation = 'horizontal')
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %% [markdown]
# ### find the first discrete difference of objects

# %%
iris['sepal_width'].diff()
# Out:
# 0      NaN
# 1     -0.5
# 2      0.2
# 3     -0.1
# 4      0.5
#       ...
# 145   -0.3
# 146   -0.5
# 147    0.5
# 148    0.4
# 149   -0.4
# Name: sepal_width, Length: 150, dtype: float64

# %%
iris['sepal_width'].diff().plot(kind = 'hist', stacked = True, bins = 20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.diff().head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           NaN          NaN           NaN          NaN
# 1          -0.2         -0.5           0.0          0.0
# 2          -0.2          0.2          -0.1          0.0
# 3          -0.1         -0.1           0.2          0.0
# 4           0.4          0.5          -0.1          0.0

# %%
df.diff().hist(color = 'b', alpha = 0.8, figsize=(8,8))
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %% [markdown]
# ### Scatter Plots

# %%
df.plot.scatter(color='b' , x = 'sepal_length', y = 'petal_length')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', label = 'Length');
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
df.plot.scatter(x = 'sepal_width', y = 'petal_width', label = 'Width', ax = ax, color = 'g')
# Out:
# <AxesSubplot:title={'center':'Iris Dataset'}, xlabel='sepal_width', ylabel='petal_width'>

# %%
df.plot.scatter(x = 'sepal_width', y = 'petal_length', label = 'Width', ax = ax, color = 'r')
# Out:
# <AxesSubplot:title={'center':'Iris Dataset'}, xlabel='sepal_width', ylabel='petal_length'>

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width', s = 100)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %% [markdown]
# ### HexaBin

# %%
df.plot.hexbin(x = 'sepal_length', y = 'petal_length', gridsize = 4, C = 'sepal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %% [markdown]
# ### PieCharts for First Row

# %%
d = df.iloc[0]
d
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
d.plot.pie(figsize = (8,8))
# Out:
# <AxesSubplot:ylabel='0'>

# %% [markdown]
# ### PieCharts For Top 3 Rows

# %%
d = df.head(3).T
d
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
d.plot.pie(subplots = True, figsize = (20, 20))
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>], dtype=object)

# %%
d.plot.pie(subplots = True, figsize = (20, 20), fontsize = 26, autopct = '%.2f')
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>], dtype=object)

# %% [markdown]
# ### Scatter Matrix OR Trellis Visualization

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(df, figsize= (8,8), diagonal='kde', color = 'b')
plt.show()

# %% [markdown]
# ### Andrew Curve For Each Column Of IRIS DataSet

# %%
from pandas.plotting import andrews_curves

# %%
andrews_curves(df, 'sepal_width')
# Out:
# <AxesSubplot:>

# %%
andrews_curves(df, 'petal_width')
# Out:
# <AxesSubplot:>

# %%
andrews_curves(df, 'sepal_length')
# Out:
# <AxesSubplot:>

# %%
andrews_curves(df, 'petal_length')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Some Other Visualizations

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [sepal_length, sepal_width, petal_length, petal_width]
# Index: []

# %%
x = df.drop(['sepal_width', 'petal_width'], axis = 1)
x.head()
# Out:
#    sepal_length  petal_length
# 0           5.1           1.4
# 1           4.9           1.4
# 2           4.7           1.3
# 3           4.6           1.5
# 4           5.0           1.4

# %%
y = df.drop(['sepal_length', 'petal_length'], axis = 1)
y.head()
# Out:
#    sepal_width  petal_width
# 0          3.5          0.2
# 1          3.0          0.2
# 2          3.2          0.2
# 3          3.1          0.2
# 4          3.6          0.2

# %%
x.plot(figsize=(10,5), x_compat = True)
# Out:
# <AxesSubplot:>

# %%
y.plot(figsize=(10,5), x_compat = True)
# Out:
# <AxesSubplot:>

# %%
df.plot(subplots = True)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)

# %%
df.plot(subplots = True, sharex = False, layout = (2,3), figsize = (16,8))
plt.tight_layout()
