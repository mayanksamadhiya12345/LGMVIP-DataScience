# %% [markdown]
# # EDA on Terrorism Dataset
#
# ## Mayank Samadhiya
#
# ## Vit Bhopal University
#
# ## LetsGrowMore
#
# ### LinkDin Profile ----> https://www.linkedin.com/in/mayank-samadhiya-6827301a7/
#
# ### GitHub Profile ----> https://github.com/mayanksamadhiya12345¶

# %%
# here we are declaring liberaries 

import numpy as np                           # for mathematical operations
import pandas as pd                          # for data analysis
import seaborn as sns                        # for loadinf the data
import matplotlib.pyplot as plt              # for data visualization
# %matplotlib inline

sns.set()

# %% [markdown]
# # Importing Datasets
#
# 1. First we load our dataset from the csv file
#
# 2. After loading it is important to check the complete information of data as it can indication many of the hidden infomation     such as null values in a column or a row
#
# 3. Check whether any null values are there or not. if it is present then following can be done, A. Imputing data using           Imputation method in sklearn B. Filling NaN values with mean, median and mode using fillna() method
#
# 4. Describe data --> which can give statistical analysis

# %%
df = pd.read_csv(r"Terrorism_Dataset.csv")
df.head()
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region                   region_txt provstate  \
# 0  Dominican Republic       2  Central America & Caribbean       NaN
# 1              Mexico       1                North America   Federal
# ...

# %%
df.shape
# Out:
# (181691, 135)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
df.shape
# Out:
# (181691, 135)

# %%
df.shape
# Out:
# (181691, 135)

# %%
print("Country with the highest Terrosit Attacks =" , df["country_txt"].value_counts().index[0])

print("Maxmum People that have killed in an attack =" , df["nkill"].max())

print("Year with the most Number of attacks =" , df["iyear"].value_counts().idxmax())

print("Year with the least Number of attacks =" , df["iyear"].value_counts().idxmin())

print("Most Number of Attack Types =" , df["attacktype1_txt"].value_counts().idxmax())

print("Most active Groups =" , df["gname"].value_counts().index[1])
# Out:
# Country with the highest Terrosit Attacks = Iraq
# Maxmum People that have killed in an attack = 1570.0
# Year with the most Number of attacks = 2014
# Year with the least Number of attacks = 1971
# Most Number of Attack Types = Bombing/Explosion
# Most active Groups = Taliban

# %% [markdown]
# ### now check for null values or insufficient data

# %%
df.isna().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %% [markdown]
# ### there are so many null values but some columns are hidden , so let's unhide them firstly

# %%
nan_values = df.isna()
nan_columns = nan_values.any()

col_with_nan = df.columns[nan_columns].tolist()
col_with_nan
# Out:
# ['approxdate',
#  'resolution',
#  'provstate',
#  'city',
#  'latitude',
#  'longitude',
#  'specificity',
#  'location',
#  'summary',
#  'doubtterr',
#  'alternative',
#  'alternative_txt',
#  'multiple',
#  'attacktype2',
#  'attacktype2_txt',
#  'attacktype3',
#  'attacktype3_txt',
#  'targsubtype1',
#  'targsubtype1_txt',
#  'corp1',
#  'target1',
#  'natlty1',
#  'natlty1_txt',
#  'targtype2',
#  'targtype2_txt',
#  'targsubtype2',
#  'targsubtype2_txt',
#  'corp2',
#  'target2',
#  'natlty2',
#  'natlty2_txt',
#  'targtype3',
#  'targtype3_txt',
#  'targsubtype3',
#  'targsubtype3_txt',
#  'corp3',
#  'target3',
#  'natlty3',
#  'natlty3_txt',
#  'gsubname',
#  'gname2',
#  'gsubname2',
#  'gname3',
#  'gsubname3',
#  'motive',
#  'guncertain1',
#  'guncertain2',
#  'guncertain3',
#  'nperps',
#  'nperpcap',
#  'claimed',
#  'claimmode',
#  'claimmode_txt',
#  'claim2',
#  'claimmode2',
#  'claimmode2_txt',
#  'claim3',
#  'claimmode3',
#  'claimmode3_txt',
#  'compclaim',
# ...

# %% [markdown]
# ### so many nan columns here so explore and process them one by one

# %%
df.rename(columns={'iyear':'Year','imonth':'Month','iday':'Day','gname':'Group','country_txt':'Country','provstate':'State',
                   'region_txt':'Region','longitude':'Longitude','summary':'Summary','attacktype1_txt':'Attacktype',
                   'targtype1_txt':'Targettype','nkill':'kill','weaptype1_txt':'Weapon',
                   'nwound':'Wound'},inplace=True)

# %%
pd.set_option("display.max_columns",None)
print(df.dtypes)
# Out:
# eventid        int64
# Year           int64
# Month          int64
# Day            int64
# approxdate    object
#                ...
# INT_LOG        int64
# INT_IDEO       int64
# INT_MISC       int64
# INT_ANY        int64
# related       object
# Length: 135, dtype: object

# %% [markdown]
# #### Not all columns are necessory for us some are unnecessory so take only those columns that are necessory for analysis

# %%
df = df[['Year','Month','Day','Country','State','Region','city','latitude','Longitude',
         'Attacktype','kill','Wound','target1','Summary','Group','Targettype','Weapon','motive']]

# %%
df.head()
# Out:
#    Year  Month  Day             Country    State                       Region  \
# 0  1970      7    2  Dominican Republic      NaN  Central America & Caribbean
# 1  1970      0    0              Mexico  Federal                North America
# 2  1970      1    0         Philippines   Tarlac               Southeast Asia
# 3  1970      1    0              Greece   Attica               Western Europe
# 4  1970      1    0               Japan  Fukouka                    East Asia
#
#             city   latitude   Longitude                      Attacktype  kill  \
# 0  Santo Domingo  18.456792  -69.951164                   Assassination   1.0
# 1    Mexico city  19.371887  -99.086624     Hostage Taking (Kidnapping)   0.0
# 2        Unknown  15.478598  120.599741                   Assassination   1.0
# 3         Athens  37.997490   23.762728               Bombing/Explosion   NaN
# 4        Fukouka  33.580412  130.396361  Facility/Infrastructure Attack   NaN
#
# ...

# %%
df.count()
# Out:
# Year          181691
# Month         181691
# Day           181691
# Country       181691
# State         181270
# Region        181691
# city          181257
# latitude      177135
# Longitude     177134
# Attacktype    181691
# kill          171378
# Wound         165380
# target1       181055
# Summary       115562
# Group         181691
# Targettype    181691
# Weapon        181691
# motive         50561
# dtype: int64

# %% [markdown]
# Not all the columns are having the same count values it means some null values are there

# %% [markdown]
# ### Now again check for the null values

# %%
df.isnull().sum()
# Out:
# Year               0
# Month              0
# Day                0
# Country            0
# State            421
# Region             0
# city             434
# latitude        4556
# Longitude       4557
# Attacktype         0
# kill           10313
# Wound          16311
# target1          636
# Summary        66129
# Group              0
# Targettype         0
# Weapon             0
# motive        131130
# dtype: int64

# %% [markdown]
# we found that here null values are present

# %% [markdown]
# ### HeatMap For Visualizing The Null Values

# %%
plt.figure(figsize=(8,5))
sns.heatmap(df.isnull() , yticklabels=False , cbar=False , cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Conclusion Of the heatmap
#
# #### Columns with the null values are
#     1. city
#     2. latitude
#     3. longitude
#     4. kill
#     5. wound
#     6. summary
#     7. motive
#
# as we can observe that most null values are present in    the 'motive' and 'summary' column which is also not much informative so from our dataset we can drom them
#
# apart from this , 'latitude' and 'longitude' column is also not useful for the analysis part so we will remove them also

# %% [markdown]
# ### Filling 'unknown' where there is null values in state and city

# %%
df['State'].fillna("unknown" , inplace=True)
df['city'].fillna("unknown" , inplace=True)

# %% [markdown]
# ### Filling '0' where null values

# %%
df['Wound'] = df['Wound'].fillna(0);
df['kill'] = df['kill'].fillna(0);
df['casualities'] = df['kill'] + df['Wound']

# %%
df.head()
# Out:
#    Year  Month  Day             Country    State                       Region  \
# 0  1970      7    2  Dominican Republic  unknown  Central America & Caribbean
# 1  1970      0    0              Mexico  Federal                North America
# 2  1970      1    0         Philippines   Tarlac               Southeast Asia
# 3  1970      1    0              Greece   Attica               Western Europe
# 4  1970      1    0               Japan  Fukouka                    East Asia
#
#             city   latitude   Longitude                      Attacktype  kill  \
# 0  Santo Domingo  18.456792  -69.951164                   Assassination   1.0
# 1    Mexico city  19.371887  -99.086624     Hostage Taking (Kidnapping)   0.0
# 2        Unknown  15.478598  120.599741                   Assassination   1.0
# 3         Athens  37.997490   23.762728               Bombing/Explosion   0.0
# 4        Fukouka  33.580412  130.396361  Facility/Infrastructure Attack   0.0
#
# ...

# %% [markdown]
# ### Drop all columns with null values

# %%
df.dropna(axis=1,inplace=True)

# %%
df.head()
# Out:
#    Year  Month  Day             Country    State                       Region  \
# 0  1970      7    2  Dominican Republic  unknown  Central America & Caribbean
# 1  1970      0    0              Mexico  Federal                North America
# 2  1970      1    0         Philippines   Tarlac               Southeast Asia
# 3  1970      1    0              Greece   Attica               Western Europe
# 4  1970      1    0               Japan  Fukouka                    East Asia
#
#             city                      Attacktype  kill  Wound  \
# 0  Santo Domingo                   Assassination   1.0    0.0
# 1    Mexico city     Hostage Taking (Kidnapping)   0.0    0.0
# 2        Unknown                   Assassination   1.0    0.0
# 3         Athens               Bombing/Explosion   0.0    0.0
# 4        Fukouka  Facility/Infrastructure Attack   0.0    0.0
#
#                                 Group                   Targettype  \
# ...

# %%
df.describe()
# Out:
#                 Year          Month            Day           kill  \
# count  181691.000000  181691.000000  181691.000000  181691.000000
# mean     2002.638997       6.467277      15.505644       2.266860
# std        13.259430       3.388303       8.814045      11.227057
# min      1970.000000       0.000000       0.000000       0.000000
# 25%      1991.000000       4.000000       8.000000       0.000000
# 50%      2009.000000       6.000000      15.000000       0.000000
# 75%      2014.000000       9.000000      23.000000       2.000000
# max      2017.000000      12.000000      31.000000    1570.000000
#
#                Wound    casualities
# count  181691.000000  181691.000000
# mean        2.883296       5.150156
# std        34.309747      40.555416
# min         0.000000       0.000000
# 25%         0.000000       0.000000
# 50%         0.000000       1.000000
# 75%         2.000000       4.000000
# max      8191.000000    9574.000000

# %% [markdown]
# ## Now its look Pretty Well

# %% [markdown]
# ## DATA VISUALIZATION ON TERRORISM DATASET

# %% [markdown]
# #### countrywise attacks

# %%
plt.rcParams["figure.figsize"] = 8 , 5
sns.barplot(x=df["Country"].value_counts()[:20].index,y=df["Country"].value_counts()[:20].values)
plt.ylabel("Number Of Total Attacks" , fontsize=17)
plt.xticks(rotation=90)
plt.xlabel("Attack Region" , fontsize=17)
plt.title("Country-Wise Attacks Bar-Plot" , fontsize=25 , fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Country-Wise Attacks Bar-Plot')

# %% [markdown]
# #### monthwise attacks

# %%
plt.rcParams["figure.figsize"] = 8 , 5
sns.barplot(x=df["Month"].value_counts()[:20].index,y=df["Month"].value_counts()[:20].values)
plt.ylabel("Number Of Total Attacks" , fontsize=17)
plt.xticks(rotation=90)
plt.xlabel("Attack Month" , fontsize=17)
plt.title("Month-Wise Attacks Bar-Plot" , fontsize=25 , fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Month-Wise Attacks Bar-Plot')

# %% [markdown]
# #### attacks in different regions

# %%
pd.crosstab(df.Year,df.Region).plot(kind='area',stacked=False)
plt.title("Terrorist Activities By Regions In Each Year",fontsize=24)
plt.ylabel("Number Of Attacks",fontsize=18)
plt.xlabel("Year",fontsize=18)
plt.show()

# %% [markdown]
# #### Number Of Attacks Over Different Cities

# %%
df['city'].value_counts().to_frame().sort_values('city',axis=0,ascending=False).head(10).plot(kind='bar',color='r')
plt.xticks(rotation=50)
plt.xlabel("city",fontsize=15)
plt.ylabel("Number Of Attacks",fontsize=15)
plt.title("Top 10 Most Effected Cities",fontsize=20,fontweight="bold")
plt.show()

# %% [markdown]
# #### Attacks By Different Groups

# %%
plt.rcParams["figure.figsize"] = 8 , 5
sns.barplot(x=df["Group"].value_counts()[:20].index,y=df["Group"].value_counts()[:20].values)
plt.ylabel("Number Of Total Attacks" , fontsize=17)
plt.xticks(rotation=90)
plt.xlabel("Attack Group" , fontsize=17)
plt.title("Attack By Group Bar-Plot" , fontsize=25 , fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Attack By Group Bar-Plot')

# %% [markdown]
# #### Number Of Kills by Each Terrorist Organisation in Each Country

# %%
group = df[['Group','Country','kill']]
group = group.groupby(['Group','Country'],axis=0).sum().sort_values('kill',ascending=False).drop('Unknown').reset_index().head(10)
group
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\pandas\core\generic.py:4153: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#                                               Group      Country     kill
# 0       Islamic State of Iraq and the Levant (ISIL)         Iraq  31058.0
# 1                                           Taliban  Afghanistan  29269.0
# 2                                        Boko Haram      Nigeria  16917.0
# 3                                 Shining Path (SL)         Peru  11595.0
# 4           Liberation Tigers of Tamil Eelam (LTTE)    Sri Lanka  10928.0
# 5                                        Al-Shabaab      Somalia   8176.0
# 6  Farabundo Marti National Liberation Front (FMLN)  El Salvador   8019.0
# 7       Islamic State of Iraq and the Levant (ISIL)        Syria   6883.0
# ...

# %% [markdown]
# #### Number Of People That Killed By the Different Types OF attack

# %%
df[['Attacktype','kill']].groupby(['Attacktype'],axis=0).sum().plot(kind='bar',figsize=(10,7),color='r')
plt.xticks(rotation=50)
plt.title("Number Of Killed",fontsize=18)
plt.ylabel("Number Of People",fontsize=18)
plt.xlabel=("Attac Type")
plt.show()

# %% [markdown]
# #### Total Number Of People That Killed By the Attack in Each Country

# %%
countryKill = df.pivot_table(columns='Country' , values='kill',aggfunc='sum')
countryKill
# Out:
# Country  Afghanistan  Albania  Algeria  Andorra  Angola  Antigua and Barbuda  \
# kill         39384.0     42.0  11066.0      0.0  3043.0                  0.0
#
# Country  Argentina  Armenia  Australia  Austria  Azerbaijan  Bahamas  Bahrain  \
# kill         490.0     37.0       23.0     30.0       258.0      1.0     44.0
#
# Country  Bangladesh  Barbados  Belarus  Belgium  Belize  Benin  Bhutan  \
# kill         1244.0      76.0     14.0     79.0     3.0    0.0     9.0
#
# Country  Bolivia  Bosnia-Herzegovina  Botswana  Brazil  Brunei  Bulgaria  \
# kill        42.0                79.0      11.0   203.0     0.0      28.0
#
# Country  Burkina Faso  Burundi  Cambodia  Cameroon  Canada  \
# kill            134.0   4205.0     543.0    2347.0   365.0
#
# Country  Central African Republic    Chad  Chile   China  Colombia  Comoros  \
# kill                       1990.0  1119.0  228.0  1008.0   14698.0      1.0
#
# ...

# %% [markdown]
# ## Result
#
#    1. country with the most attacks : IRAQ
#    2. city with the most attacks : BAGHDAD
#    3. Region with the most attacks : MIDDLE EAST & NORTH AFRICA
#    4. year with the most attacks and most people killed : 2014
#    5. month with the most attacks : MAY
#    6. Group with the most attacks : TALIBAN
#    7. most attack types : BOMBING/EXPLOSION
#    8. country with the most people killed in terror attack : AFGHANISTAN
#    9. terror type which killed the most : ARMED ASSAULT
#
#
#
#  ## HOTZONE OF TERRORISM : IRAQ
